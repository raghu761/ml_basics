# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget -O FuelConsumption.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# Out:
# --2020-04-15 15:05:57--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72629 (71K) [text/csv]
# Saving to: ‘FuelConsumption.csv’
#
# FuelConsumption.csv 100%[===================>]  70.93K  22.3KB/s    in 3.2s
#
# 2020-04-15 15:06:08 (22.3 KB/s) - ‘FuelConsumption.csv’ saved [72629/72629]

# %%
df=pd.read_csv('FuelConsumption.csv')
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df.tail()
# Out:
#       MODELYEAR   MAKE     MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 1062       2014  VOLVO  XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO  XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO  XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO  XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO  XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
cdf=df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]

# %%
cdf.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244

# %%
plt.scatter(cdf.ENGINESIZE,cdf.CO2EMISSIONS)
plt.xlabel('engine size ')
plt.ylabel('co2 emission ')
# Out:
# Text(0, 0.5, 'co2 emission ')

# %%
plt.scatter(cdf.FUELCONSUMPTION_COMB,cdf.CO2EMISSIONS)
plt.xlabel("fuel consumption ")
plt.ylabel("co2 emmission ")
# Out:
# Text(0, 0.5, 'co2 emmission ')

# %%
plt.scatter(cdf.CYLINDERS,cdf.CO2EMISSIONS)
plt.xlabel("cylinders ")
plt.ylabel("co2 emmission")
# Out:
# Text(0, 0.5, 'co2 emmission')

# %%
len(df)
# Out:
# 1067

# %%
msk=np.random.rand(len(df))<0.8
test=cdf[msk]
train=cdf[~msk]

# %%
test
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0            2.0          4                   8.5           196
# 1            2.4          4                   9.6           221
# 2            1.5          4                   5.9           136
# 3            3.5          6                  11.1           255
# 5            3.5          6                  10.0           230
# ...          ...        ...                   ...           ...
# 1060         3.0          6                  11.5           264
# 1061         3.2          6                  11.2           258
# 1062         3.0          6                  11.8           271
# 1064         3.0          6                  11.8           271
# 1065         3.2          6                  11.3           260
#
# [862 rows x 4 columns]

# %%
train
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 4            3.5          6                  10.6           244
# 10           2.4          4                   9.8           225
# 14           4.7          8                  14.7           338
# 15           4.7          8                  15.4           354
# 16           4.7          8                  14.7           338
# ...          ...        ...                   ...           ...
# 1032         2.0          4                   7.2           194
# 1035         1.8          4                   8.2           189
# 1042         1.4          4                   5.4           124
# 1063         3.2          6                  11.5           264
# 1066         3.2          6                  12.8           294
#
# [205 rows x 4 columns]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (train_x, train_y)
print(regr.coef_)
print(regr.intercept_)
# Out:
# [[40.85524186]]
# [119.51126951]

# %%
train_x
# Out:
# array([[3.5],
#        [2.4],
#        [4.7],
#        [4.7],
#        [4.7],
#        [5.9],
#        [2. ],
#        [2. ],
#        [2. ],
#        [3. ],
#        [3. ],
#        [4.2],
#        [5.2],
#        [5.2],
#        [3. ],
#        [2. ],
#        [6. ],
#        [2. ],
#        [3. ],
#        [3. ],
#        [2. ],
#        [4.4],
#        [4.4],
#        [4.4],
#        [2. ],
#        [3. ],
#        [3. ],
#        [3.6],
#        [3.6],
#        [2. ],
#        [3.6],
#        [3.6],
#        [6.2],
#        [3.6],
#        [3.6],
#        [5.3],
#        [5.3],
#        [6. ],
#        [2.4],
#        [4.3],
#        [1.4],
#        [1.4],
#        [3.6],
#        [5.7],
#        [3.6],
#        [3.6],
#        [3.6],
#        [3.6],
#        [6.4],
#        [2. ],
#        [2.4],
#        [3.6],
#        [3.6],
#        [1.4],
#        [1.4],
#        [1.4],
#        [2. ],
#        [4.6],
#        [5.4],
#        [5.4],
#        [1.6],
#        [3.5],
#        [3.5],
#        [3.5],
#        [3.7],
#        [3.7],
#        [5. ],
#        [5. ],
#        [6.2],
#        [1.6],
#        [1. ],
#        [1.6],
#        [3.5],
#        [1.5],
#        [1.5],
#        [3.7],
#        [3.7],
#        [3.5],
#        [3.5],
#        [3.5],
#        [1.6],
#        [1.6],
#        [4.3],
#        [5.3],
#        [5.3],
#        [6. ],
#        [5.3],
#        [5.3],
#        [2.4],
#        [5.3],
#        [5.3],
#        [6.2],
#        [5.3],
#        [5.3],
#        [5.3],
#        [2.4],
#        [1.8],
#        [1.5],
#        [1.5],
#        [3.5],
#        [2. ],
#        [3.8],
#        [2. ],
#        [1.6],
#        [3.7],
#        [3.5],
#        [3.5],
#        [3.7],
#        [3.5],
#        [5. ],
#        [2.4],
#        [2.4],
#        [3.2],
#        [2. ],
#        [2.4],
#        [2.4],
#        [3.6],
#        [3.6],
#        [1.6],
#        [2.4],
#        [1.6],
#        [2. ],
#        [5.2],
#        [2. ],
#        [5. ],
#        [2.5],
#        [3.5],
#        [3.5],
#        [3.5],
#        [3.7],
#        [3. ],
#        [2. ],
#        [3.7],
#        [1.5],
#        [2. ],
#        [2.5],
#        [2.5],
#        [2. ],
#        [2. ],
#        [3.5],
#        [6.2],
#        [5.5],
#        [3.5],
#        [3.5],
#        [5.5],
#        [2.1],
#        [3. ],
#        [5.5],
#        [5.5],
#        [3.5],
#        [6.2],
#        [6.2],
#        [1.6],
#        [1.6],
#        [1.6],
#        [1.6],
#        [1.6],
#        [1.6],
#        [1.6],
#        [2. ],
#        [2.4],
#        [3.7],
#        [2.5],
#        [5.6],
#        [2.5],
#        [1.6],
#        [3.5],
#        [5.6],
#        [1.6],
#        [1.6],
#        [3.4],
#        [3.8],
#        [3.6],
#        [3.4],
#        [3.6],
#        [3.6],
#        [2. ],
#        [1.3],
#        [1.8],
#        [1.8],
#        [1. ],
#        [2. ],
#        [2. ],
#        [2.5],
#        [2.5],
#        [3.6],
#        [3.5],
#        [1.8],
#        [3.5],
#        [3.5],
#        [2.5],
#        [5.7],
#        [2.7],
#        [3.5],
#        [1.5],
#        [1.8],
#        [2. ],
#        [2.5],
#        [2. ],
#        [2.5],
#        [2. ],
#        [1.8],
#        [1.4],
#        [3.2],
#        [3.2]])

# %%
train_y
# Out:
# array([[244],
#        [225],
#        [338],
#        [354],
#        [338],
#        [359],
#        [214],
#        [214],
#        [235],
#        [251],
#        [258],
#        [407],
#        [354],
#        [409],
#        [262],
#        [209],
#        [380],
#        [202],
#        [230],
#        [237],
#        [209],
#        [338],
#        [317],
#        [338],
#        [209],
#        [278],
#        [253],
#        [283],
#        [264],
#        [246],
#        [248],
#        [262],
#        [322],
#        [290],
#        [242],
#        [344],
#        [380],
#        [411],
#        [244],
#        [271],
#        [191],
#        [182],
#        [242],
#        [308],
#        [242],
#        [258],
#        [237],
#        [258],
#        [317],
#        [186],
#        [198],
#        [278],
#        [250],
#        [182],
#        [179],
#        [193],
#        [138],
#        [373],
#        [360],
#        [382],
#        [209],
#        [299],
#        [292],
#        [317],
#        [264],
#        [264],
#        [340],
#        [318],
#        [414],
#        [175],
#        [152],
#        [184],
#        [278],
#        [196],
#        [186],
#        [235],
#        [244],
#        [271],
#        [229],
#        [251],
#        [218],
#        [232],
#        [347],
#        [344],
#        [380],
#        [413],
#        [299],
#        [277],
#        [230],
#        [317],
#        [294],
#        [322],
#        [294],
#        [317],
#        [294],
#        [200],
#        [161],
#        [145],
#        [159],
#        [244],
#        [198],
#        [255],
#        [214],
#        [196],
#        [235],
#        [172],
#        [189],
#        [253],
#        [244],
#        [294],
#        [230],
#        [232],
#        [267],
#        [209],
#        [235],
#        [216],
#        [278],
#        [308],
#        [225],
#        [253],
#        [207],
#        [262],
#        [400],
#        [225],
#        [347],
#        [138],
#        [175],
#        [244],
#        [255],
#        [281],
#        [301],
#        [189],
#        [290],
#        [177],
#        [161],
#        [175],
#        [168],
#        [235],
#        [221],
#        [242],
#        [352],
#        [301],
#        [235],
#        [235],
#        [297],
#        [230],
#        [278],
#        [356],
#        [304],
#        [225],
#        [361],
#        [361],
#        [179],
#        [179],
#        [168],
#        [179],
#        [196],
#        [207],
#        [191],
#        [191],
#        [218],
#        [269],
#        [175],
#        [380],
#        [283],
#        [198],
#        [271],
#        [398],
#        [152],
#        [177],
#        [232],
#        [274],
#        [313],
#        [225],
#        [251],
#        [262],
#        [218],
#        [143],
#        [184],
#        [182],
#        [147],
#        [179],
#        [179],
#        [258],
#        [198],
#        [269],
#        [221],
#        [177],
#        [264],
#        [189],
#        [218],
#        [384],
#        [274],
#        [253],
#        [168],
#        [196],
#        [209],
#        [221],
#        [197],
#        [218],
#        [194],
#        [189],
#        [124],
#        [264],
#        [294]])

# %%
type(regr.coef_)
coeff=regr.coef_
coeff
# Out:
# array([[40.85524186]])

# %%
type(regr.intercept_)
intercept=regr.intercept_
intercept
# Out:
# array([119.51126951])

# %%
plt.scatter(train_x,train_y)
plt.plot(train_x,intercept[0]+coeff[0][0]*train_x,'-r')
plt.xlabel('size of the cylinder')
plt.ylabel('co2 emission')
plt.show()
